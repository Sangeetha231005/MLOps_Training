# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangeetha231005/MLops-training/blob/main/One_Hot_Encoding_Flood_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **One Hot Encoding - Flood Detection**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    '/content/drive/MyDrive/Flood_detection/flood_dataset.csv',
    low_memory=False
)

# %%
df.head()
# Out:
#     gsim_code  latitude  longitude  year  Annual peak discharge  \
# 0  AR_0000002    -25.28     -65.38  1944                329.364
# 1  AR_0000002    -25.28     -65.38  1963                519.160
# 2  AR_0000002    -25.28     -65.38  1965                367.600
# 3  AR_0000017    -27.40     -65.98  1956                 60.150
# 4  AR_0000017    -27.40     -65.98  1960                 74.620
#
#    Unit peak discharge country countryname continentcode  \
# 0             0.046985      AR   Argentina            SA
# 1             0.074061      AR   Argentina            SA
# 2             0.052440      AR   Argentina            SA
# 3             0.069699      AR   Argentina            SA
# 4             0.086466      AR   Argentina            SA
#
#    Annual Mean Temperature  ...  SecondThird Bifurcationratio  \
# 0                11.373328  ...                           4.8
# 1                11.373328  ...                           4.8
# ...

# %%
df = df.drop([
    'gsim_code',
    'countryname',
    'continentcode',
    'year'
], axis=1)

# %%
df.shape
# Out:
# (45932, 89)

# %%
df.isnull().sum()
# Out:
# latitude                    0
# longitude                   0
# Annual peak discharge       0
# Unit peak discharge         0
# country                    74
#                          ...
# Number of Dams              0
# Climate Type                0
# Landcover Type             52
# Soil Type                1494
# Lithology Type           1222
# Length: 89, dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

print(missing_percentage)
# Out:
# latitude                 0.000000
# longitude                0.000000
# Annual peak discharge    0.000000
# Unit peak discharge      0.000000
# country                  0.161108
#                            ...
# Number of Dams           0.000000
# Climate Type             0.000000
# Landcover Type           0.113211
# Soil Type                3.252634
# Lithology Type           2.660455
# Length: 89, dtype: float64

# %%
df = df.loc[:, missing_percentage < 50]

# %%
df.shape
# Out:
# (45932, 69)

# %%
df.isnull().sum()
# Out:
# latitude                    0
# longitude                   0
# Annual peak discharge       0
# Unit peak discharge         0
# country                    74
#                          ...
# Number of Dams              0
# Climate Type                0
# Landcover Type             52
# Soil Type                1494
# Lithology Type           1222
# Length: 69, dtype: int64

# %%
df = df.fillna(df.mean(numeric_only=True))

# %%
df = df.fillna('Unknown')

# %%
df.dtypes
# Out:
# latitude                 float64
# longitude                float64
# Annual peak discharge    float64
# Unit peak discharge      float64
# country                   object
#                           ...
# Number of Dams             int64
# Climate Type              object
# Landcover Type            object
# Soil Type                 object
# Lithology Type            object
# Length: 69, dtype: object

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print(categorical_columns)
# Out:
# Index(['country', 'Climate Type', 'Landcover Type', 'Soil Type',
#        'Lithology Type'],
#       dtype='object')

# %%
df = pd.get_dummies(
    df,
    columns=[
        'country',
        'Climate Type',
        'Landcover Type',
        'Soil Type',
        'Lithology Type'
    ]
)

# %%
df.head()
# Out:
#    latitude  longitude  Annual peak discharge  Unit peak discharge  \
# 0    -25.28     -65.38                329.364             0.046985
# 1    -25.28     -65.38                519.160             0.074061
# 2    -25.28     -65.38                367.600             0.052440
# 3    -27.40     -65.98                 60.150             0.069699
# 4    -27.40     -65.98                 74.620             0.086466
#
#    Annual Mean Temperature  Mean Diurnal Range  Isothermality  \
# 0                11.373328           14.494187      58.613892
# 1                11.373328           14.494187      58.613892
# 2                11.373328           14.494187      58.613892
# 3                13.961597           14.924928      54.608349
# 4                13.961597           14.924928      54.608349
#
#    Temperature Seasonality  Max Temperature of Warmest Month  \
# 0               369.461182                          22.68236
# 1               369.461182                          22.68236
# ...

# %%
X = df[[
    'latitude',
    'longitude',
    'Annual Mean Temperature',
    'Annual Precipitation',
    'Drainage Area',
    'Basin Relief',
    'Drainage Density',
    'Number of Dams'
]]

# %%
y = df['Annual peak discharge']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=10
)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
print(predictions)
# Out:
# [675.25377894  98.77452942  -9.18382344 ...  99.45516238 305.06458751
#  401.46713529]

# %%
model.score(X_test, y_test)
# Out:
# 0.04911596977323296
