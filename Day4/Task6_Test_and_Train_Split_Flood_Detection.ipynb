# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangeetha231005/MLops-training/blob/main/Test_and_Train_Split_Flood_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Train Test Split - Flood Detection**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Flood_detection/flood.csv')

# %%
df.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
# 3                 4                   4                2              7
# 4                 3                   7                5              2
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
# 3             3              4            1          4                      6
# 4             5              8            5          2                      7
#
# ...

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
plt.scatter(df['MonsoonIntensity'], df['FloodProbability'])
plt.xlabel("MonsoonIntensity")
plt.ylabel("FloodProbability")
plt.show()

# %%
X = df[[
    'MonsoonIntensity',
    'TopographyDrainage',
    'RiverManagement',
    'Deforestation',
    'Urbanization',
    'ClimateChange',
    'DamsQuality',
    'Siltation',
    'AgriculturalPractices',
    'Encroachments'
]]

# %%
y = df['FloodProbability']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=10
)

# %%
X_train
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 17613                 5                   6                7              3
# 29059                12                   8                7             11
# 22180                 6                   5                2              5
# 7529                  2                   8                5              4
# 41493                 9                   7                4              3
# ...                 ...                 ...              ...            ...
# 40059                 5                   2                5              3
# 28017                 5                   5                4              6
# 29199                 3                   4                4              3
# 40061                 4                   6                1              2
# 17673                 2                   3                0              6
#
# ...

# %%
X_test
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 27632                 5                   5                4              1
# 36119                 3                   3                8              9
# 4796                  5                   4                6              8
# 3648                  3                   8                6              7
# 24501                 5                   4                5              7
# ...                 ...                 ...              ...            ...
# 12829                 9                   4                1              5
# 41873                 3                   6                5              5
# 5356                  2                   5                6              4
# 20046                 8                   4                4             10
# 25470                 7                   5                3              9
#
# ...

# %%
y_train
# Out:
# 17613    0.525
# 29059    0.625
# 22180    0.510
# 7529     0.470
# 41493    0.455
#          ...
# 40059    0.440
# 28017    0.390
# 29199    0.510
# 40061    0.450
# 17673    0.405
# Name: FloodProbability, Length: 35000, dtype: float64

# %%
y_test
# Out:
# 27632    0.505
# 36119    0.465
# 4796     0.550
# 3648     0.525
# 24501    0.525
#          ...
# 12829    0.525
# 41873    0.555
# 5356     0.525
# 20046    0.525
# 25470    0.550
# Name: FloodProbability, Length: 15000, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([0.45911199, 0.52468786, 0.5306156 , ..., 0.49467072, 0.5243076 ,
#        0.54458685])

# %%
model.score(X_test, y_test)
# Out:
# 0.5011358782001969
